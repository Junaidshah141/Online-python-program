# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# df["cast"] = df["cast"].replace(np.nan, 0)
#arr = df.iloc[1, df["cast"]].split(", ")
#arr


# df['no_of_cast'] = df.cast.apply(lambda x: len(str(x).split(' ')))
# df.head(5)
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.groupby("type")["country"].value_counts()
# Out:
# type     country
# Movie    United States                               2058
#          India                                        893
#          United Kingdom                               206
#          Canada                                       122
#          Spain                                         97
#                                                      ...
# TV Show  United States, Russia                          1
#          United States, Singapore                       1
#          United States, Sweden                          1
#          United States, United Kingdom, Australia       1
#          Uruguay, Germany                               1
# Name: country, Length: 847, dtype: int64

# %%
data = df.groupby(["type", "rating", "no_of_cast"])['country'].value_counts()
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4536/3873618894.py in <module>
# ----> 1 data = df.groupby(["type", "rating", "no_of_cast"])['country'].value_counts()
#       2 data.head(5)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
df.groupby('type')['rating'].value_counts()
# Out:
# type     rating
# Movie    TV-MA       2062
#          TV-14       1427
#          R            797
#          TV-PG        540
#          PG-13        490
#          PG           287
#          TV-Y7        139
#          TV-Y         131
#          TV-G         126
#          NR            75
#          G             41
#          TV-Y7-FV       5
#          NC-17          3
#          UR             3
#          66 min         1
#          74 min         1
#          84 min         1
# TV Show  TV-MA       1145
#          TV-14        733
#          TV-PG        323
#          TV-Y7        195
#          TV-Y         176
#          TV-G          94
#          NR             5
#          R              2
#          TV-Y7-FV       1
# Name: rating, dtype: int64

# %%
df.groupby(["type", "listed_in"]).count().head(20)
# Out:
#                                                           show_id  title  \
# type  listed_in
# Movie Action & Adventure                                      128    128
#       Action & Adventure, Anime Features                        1      1
#       Action & Adventure, Anime Features, Children & ...        4      4
#       Action & Adventure, Anime Features, Classic Movies        2      2
#       Action & Adventure, Anime Features, Horror Movies         1      1
#       Action & Adventure, Anime Features, Internation...       38     38
#       Action & Adventure, Anime Features, Sci-Fi & Fa...        4      4
#       Action & Adventure, Children & Family Movies              2      2
#       Action & Adventure, Children & Family Movies, C...        4      4
#       Action & Adventure, Children & Family Movies, C...        5      5
#       Action & Adventure, Children & Family Movies, C...        1      1
#       Action & Adventure, Children & Family Movies, D...        3      3
# ...
